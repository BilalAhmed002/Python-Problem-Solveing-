# %%
def findpimenumberintownumber(number: int) ->int :
    """
    """
    if not isinstance(number,int):
        raise TypeError ("Value Must be interger")
    if number<2 :
        raise ValueError("input must be greater then 1 or 2")
    for i in range (2,number) :
         if number % i == 0:
             return False
    else : 
         return True

if __name__ =="__main__":
    
    try : 
        
        lower_user_input = input("Enter the lower value")
        upper_user_input = input("Enter the upper_Value")

        if not lower_user_input.strip().isdigit():
            raise TypeError("")
        if not upper_user_input.strip().isdigit():
            raise TypeError("")
            
        lower_user_input = int(lower_user_input)
        upper_user_input = int(upper_user_input)    

        
        prime_nubmer =[]     

      
        for i in range(lower_user_input,upper_user_input):
             if findpimenumberintownumber(i):
                print(f"{i} prime number")
                prime_nubmer.append(i)
        print(prime_nubmer)
                             

        
    except Exception as e :
        print(e)
# Out:
# Enter the lower value 50
# Enter the upper_Value 90
# 53 prime number
# 59 prime number
# 61 prime number
# 67 prime number
# 71 prime number
# 73 prime number
# 79 prime number
# 83 prime number
# 89 prime number
# [53, 59, 61, 67, 71, 73, 79, 83, 89]

# %%
findpimenumberintownumber
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 findpimenumberintownumber(5)
#
# Cell In[10], line 8, in findpimenumberintownumber(number)
#       6 if number<2 :
#       7     raise ValueError("input must be greater then 1 or 2")
# ----> 8 for i in  number :
#       9      if number % i == 0:
#      10          return False
#
# TypeError: 'int' object is not iterable

# %%
nubmer =5
for i in range (2,nubmer):
    print(i)
    p
# Out:
# 2
# 3
# 4

# %%
findpimenumberintownumber(13)
# Out:
# True
