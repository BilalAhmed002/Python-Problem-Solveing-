# %%
text ="Hello my Name "
Vowels ="aeiou"
count =0
for char in text.lower():
    if char in Vowels: 
        count = count + 1
print(count)
# Out:
# 4

# %%
def Countvowels(text):
    """
    """
    Vowels ="aeiou"
    count =0
    for char in text.lower():
        if char in Vowels: 
            count = count + 1
    print(count)

# %%
Countvowels("Hello")
# Out:
# 2

# %%
def Countvowels(text:str) -> int:
    """
    """
    if not isinstance(text,str):
        raise TypeError("Input must be a String")
       
    Vowels ="aeiou"
    count = 0
    for char in text.lower():
        if char in Vowels: 
            count = count + 1
    return count
if __name__ =="__main__":

    try : 
        user_input=input("Enter the String ")
        reslut = Countvowels(user_input)
        print(reslut)

    except TypeError as e : 
        print(e)
    except Exception as e: 
        print(e)
# Out:
# Enter the String  hello
# 2
