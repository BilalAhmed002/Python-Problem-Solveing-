# %%
String="Hello My Name is Bilal Ahmed"
stringreverse =""
for char in String:
    stringreverse = char + stringreverse
print(stringreverse)
# Out:
# demhA laliB si emaN yM olleH

# %%
def reverse_string(input_String: str) -> str:
    """
    Function this Function work is reverse any String

    Args : This Function take only String 


    """
    rever_string = " "
    for char in input_String:
        rever_string = char + rever_string        
    return rever_string

# %%
reverse_string("Hello my name is bil")
# Out:
# 'lib si eman ym olleH '

# %%
def reverse_string(input_String: str) -> str:
    """
    Function this Function work is reverse any String

    Args : This Function take only String 


    """
    if not isinstance(input_String, str):
        raise TypeError("Value must be string")
    if len(input_String) == 0:
        raise ValueError("String Should not be Emptuy")        
    rever_string = " "        
    for char in input_String:
        rever_string = char + rever_string        
    return rever_string

if __name__ == "__main__" :

    try : 
        user_input=input("Enter the String")  
        result =reverse_string(user_input)
        print(result)
    except (TypeError, ValueError) as e:
        print(e)
# Out:
# Enter the String this
# siht

# %%
def reverse_stirng2
