# %%
string = "mom"
string1 = ""
for char in string:
    string1 = char + string1
if string == string1:
        print(f"String is Pandrom: {string1}")
else: 
        print(f"String is not Pandrom :{string1}")
    
#print(string1)
# Out:
# String is Pandrom: mom

# %%
def FindValueisPanandrom(userstr : str) -> str:
    """
    """
    if not isinstance(userstr, str):
        raise TypeError ("input must be string")
    if userstr =="":
        raise ValueError ("input can not be empty")
    string1 = ""
    for char in userstr:
        string1 = char + string1
    if userstr == string1:
        print(f"String is Pandrom: {string1}")
    else: 
        print(f"String is not Pandrom :{string1}")

# %%
FindValueisPanandrom("mom")
# Out:
# String is Pandrom: mom

# %%
def FindValueisPanandrom(userstr : str) -> str:
    """
    """
    if not isinstance(userstr, str):
        raise TypeError ("input must be string")
    if userstr =="":
        raise ValueError ("input can not be empty")
    string1 = ""
    for char in userstr:
        string1 = char + string1
    if userstr == string1:
        print(f"String is Pandrom: {string1}")
    else: 
        print(f"String is not Pandrom :{string1}")

if __name__=="__main__":
    try:
        user_input=input("Enter the String ").strip()
    
        reslut=FindValueisPanandrom(user_input)
        print(reslut)
    except (TypeError,ValueError) as e :
        print(e)
    except Exception as e : 
        print(e)
# Out:
# Enter the String    mom
# String is Pandrom: mom
# None
