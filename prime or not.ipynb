# %%
number = 13 

for i in range(2,number):
    if number %i==0:
        print("Value is not Prime")
        break
else : 
    print("Vale is Prime")
#

# %%
def primeornotprime(input_value : int) -> int :
    """
    """
    for i in range(2,number):
        if number %i==0:
            print("Value is not Prime")
            break
    else : 
        print("Vale is Prime")

# %%
primeornotprime(13)

# %%
def primeornotprime(input_value : int) -> int :
    """
    """
    if not isinstance(input_value,int):
        raise TypeError ("Input must be interger")
    if input_value < 2:
        raise ValueError ("Inputer must be higher on 1")
    for i in range(2,int(input_value**.5) + 1):
        if input_value % i==0:
            return False
            break
    else : 
        return True

if __name__ == "__main__" :

    try : 
        input_user = input("Enter the input")

        if not input_user.strip().isdigit():
            raise TypeError ("Input Must be Digit")

        input_value = int(input_user)
        if primeornotprime(input_value):
            print(f"{input_value} Is Prime Number")


        else : 
            print(f"{input_value} is Not Prime Nubmer ")            


    except (TypeError, ValueError) as e : 
        print (e)

    except Exception as e : 
        print(e)
# Out:
# Enter the input 52935723957892375239542054
# 52935723957892375239542054 is Not Prime Nubmer

# %%
#

# %%
print(globals)
